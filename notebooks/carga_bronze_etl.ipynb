# %%
import pandas as pd
import os
import sys
import tomllib

sys.path.append(os.path.abspath("../.secrets"))
from db_config import get_connection

print("se conecto correctamente a la base de datos")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 7
#       4 import tomllib
#       6 sys.path.append(os.path.abspath("../.secrets"))
# ----> 7 from db_config import get_connection
#       9 print("se conecto correctamente a la base de datos")
#
# ImportError: cannot import name 'get_connection' from 'db_config' (c:\Users\larag\OneDrive\Escritorio\CIENCIA DE DATOS\Big Data Aplicada\IDL 1\BDA_IDL1\.secrets\db_config.py)
